# %% [markdown]
# # Inversion with structural constraints

# %%
# %matplotlib widget

# %%
import matplotlib.pyplot as plt
import numpy as np
import pygimli as pg
import pygimli.meshtools as mt
from pygimli.physics import ert
import os

# %% [markdown]
# First we load the data and the interface

# %%
os.chdir(r'C:\Users\sydne\git\erth370\erth370-w2026-sydpas')
print(f'Directory: {os.getcwd()}')  # shows current working directory
os.makedirs(r"figures/line02/new_ball_asf1", exist_ok=True)

filename = r'data\line02\og_fromtomsnotes_mytopo\Gradient XL_A_1-2018-06-13-143156.dat'
data = ert.load(filename)
print(data)
# Out:
# 03/03/26 - 14:42:43 - pyGIMLi - INFO - could not read unified data format for ERT ... try res2dinv
# Directory: C:\Users\sydne\git\erth370\erth370-w2026-sydpas
# Data: Sensors: 81 data: 1478, nonzero entries: ['a', 'b', 'm', 'n', 'r', 'valid']

# %%
xs = np.array([s.x() for s in data.sensors()])  # an array of all elec x-positions along line

data_min = xs.min(); data_max = xs.max()

print(data_min, data_max)
# Out:
# 0.0 240.0

# %% [markdown]
# adding "topo = topo[np.argsort(topo[:,0])]"  to deal w negative vals

# %%
topo = []

topo_file = r'data\line02\line02_mytopo.txt'

with open(topo_file) as f: 
    next(f)  # skip header line
    for line in f:
        line = line.strip()
        parts = line.split()  # split using whitespace
        if len(parts) == 2:  # if data has 2 columns it is topo data so add to the list
            topo.append([float(parts[0]), float(parts[1])])

topo = np.array(topo)  # convert to numpy array

x_elec = pg.x(data)  # get x pos of all electrodes
z_elec = np.interp(x_elec, topo[:,0], topo[:,1])  # interpolate topo at each electrode

x_elec = np.array(pg.x(data))  # convert RVector to numpy

# now we ensure topo covers all electrodes at both ends
if topo[0,0] > x_elec.min():  # if topo is to the right of (after) electrode
    topo = np.vstack(([x_elec.min(), topo[0,1]], topo))
if topo[-1,0] < x_elec.max():  # if topo is to the left of (before) electrode
    topo = np.vstack((topo, [x_elec.max(), topo[-1,1]]))

# print(f'x elec: {x_elec}')
# print(f'topo[:,0]: {topo[:,0]}')
# print(f'topo[:,1]: {topo[:,1]}')


# second interp of topo at electrode positions
z_interp = np.interp(x_elec, topo[:,0], topo[:,1])

# print(f'z interp: {z_interp}')

# set electrode positions in data
data.setSensorPositions(pg.PosVector(np.c_[x_elec, z_interp]))  # combine into 2D array, convert to gimli pos vector, and update elec pos in ERT dataset

# plot to check
fig, ax = plt.subplots(figsize=(10,4)) 
ax.plot(x_elec, z_interp, 'r*')
ax.set_xlabel('Electrode Location [m]')
ax.set_ylabel('Elevation [m]')
ax.set_title('Topography')

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# K should convert measured resistance from the field to true resistivity.
# - Analytical: assumes flat ground and ideal geometry, so less accurate.
# - Numerical: solves with PDE and uses real electrode positions and topography.

# %%
# topo= pg.PosVector(topo)  # turn from array into pygimli pos vector

k0 = ert.createGeometricFactors(data)  # analytical; assumes simple geometry
data['k'] = ert.createGeometricFactors(data, numerical=True)  # numerical; solves forward PDE
# Out:
# 03/03/26 - 14:42:48 - pyGIMLi - INFO - Cache c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\physics\ert\ert.py:createGeometricFactors restored (0.0s x 6): C:\Users\sydne\AppData\Roaming\pygimli\Cache\17882742636016452856
# 03/03/26 - 14:42:48 - pyGIMLi - INFO - Cache c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\physics\ert\ert.py:createGeometricFactors restored (7.3s x 6): C:\Users\sydne\AppData\Roaming\pygimli\Cache\11198770962024468645

# %% [markdown]
# Now we shall observe the topography effect, i.e the ratio between
# the numerically computed geometry factor and the analytical formula after
# Rücker et al. (2006). We display it using a colormap with neutral white.
#
# from chat: "Topographic effect on resistivity
# - ~1: topo has little effect
# - topo > 1: ignoring topo overestimates resistivity
# - topo < 1: ignoring topo underestimates resistivity"
#
# bwr colormap directory:
# - blue: high numerical k
# - red: high analytical k
# - white: same
#
# Pseudo-depth: sensitivity location.
# - DD: dipole dipole.
# - Numbers: electrode spacing levels.
#     - Current: controls how deep the current penetrates (A-B)
#     - Potential: controls voltage sensitivity (M-N).
# - ex. DD2-3:
#     - current dipole spacing: 2 electrodes.
#     - potential dipole spacing: 3 electrodes.

# %%
fig, ax = plt.subplots(figsize=(10, 6))
_ = ert.showData(data, 
                 vals=k0/ data['k'],  # quantifies the topography effect
                 ax=ax,
                 label='Topography effect', xlabel='Distance [m]', ylabel='Pseudo-depth',
                 cMin=2/3, cMax=3/2,  # color limits
                 logScale=True, 
                 cMap="bwr"  # blue-white-red colormap
)

ax.set_title('Topography Effect on Data');

fig.savefig(r"figures/line02/new_ball_asf1/1topo_effect_on_data.png", dpi=300, bbox_inches='tight')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# If the topography effect on data looks strange (ie. no color bar, axes titles) just rerun and it'll work!!!
#
#
# We can now compute the apparent resistivity and display it, once with the
# wrong analytical formula and once with the numerical values.

# %%
data['rhoa'] = data['r'] * data['k']  # uses numerical k; converts measured resistances to apparent resist

# edit impossible negative or zero values
data['rhoa'][data['rhoa'] <= 0] = 1e-6

cmin = pg.min(data['rhoa'])
cmax = pg.max(data['rhoa'])
print(f' Min: {pg.min(data["rhoa"])}, Max: {pg.max(data["rhoa"])}')

kw = dict(cMin=cmin, cMax=cmax)  # storing key/value pairs for colour scale
fig, ax = plt.subplots(ncols=2, figsize=(12, 6))

data.show(data['r']*k0, ax=ax[0], **kw, cMap='inferno', 
          xlabel='Distance [m]', ylabel='Pseudo-depth');  # uses analytical k so assumes flat ground

data.show(ax=ax[1], **kw, cMap='inferno',
          xlabel='Distance [m]')  # uses numerical k so adds topo

ax[0].set_title('Analytical Geometric Factor; Uncorrected')  # analytical
ax[1].set_title('Numerical Geometric Factor; Corrected');  # numerical 

fig.savefig(r"figures/line02/new_ball_asf1/2uncorrected_vs_corrected_geometric.png", dpi=300, bbox_inches='tight')
# Out:
#  Min: 21.985891235363546, Max: 4214.937900169664
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# We estimate an error and do a normal inversion using the ERT manager.
# As we expect more or less layered structures, we choose a vertical
# weighting factor for the regularization of 0.5.

# %%
data.estimateError(relativeError=0.03, absoluteUError=5e-5)

fig, ax = plt.subplots(figsize=(8,8))
_ = data.show( data['err']*100, ax=ax,
    label='error estimate (%)', xlabel='Distance [m]',
    cMin=3, cMax=30)

ax.set_title('Estimated Data Error');

fig.savefig(r"figures/line02/new_ball_asf1/3est_data_error.png", dpi=300, bbox_inches='tight')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# code for storing the points

# %%
def onclick(event):
    # make sure click is inside the correct axes
    if event.inaxes != ax:
        return

    if event.xdata is not None and event.ydata is not None:
        x_line.append(event.xdata)
        z_line.append(event.ydata)

        ax.plot(event.xdata, event.ydata, 'ro', markersize=5)  # plot on SAME axes
        fig.canvas.draw_idle()

        print(f"Picked point: x={event.xdata:.2f}, z={event.ydata:.2f}")

# %% [markdown]
# mesh moment!!!!111!!!!!!
#
# **area**: range is 0.1-10, with 2-5 a regular range

# %%
depth = 50  # thickness below surface 

surface = [[x, z] for x, z in zip(x_elec, z_interp)]

bottom = [[x, z - depth] for x, z in zip(reversed(x_elec), reversed(z_interp))]

# create closed polygon
polygon_points = surface + bottom

geom = mt.createPolygon(polygon_points, isClosed=True)

# create triangular mesh inside polygon
mesh = mt.createMesh(geom, quality=25, area=5)  # area controls cell size
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 4))

pg.show(mesh, ax=ax, showMesh=True)
fig.savefig(r'figures/line02/new_ball_asf1/4meshball.png', dpi=300, bbox_inches='tight')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# > Now the data have all necessary fields ('rhoa', 'err' and 'k') so we can run
# the inversion!! First we run this bad boy so we can figure out how we would like to constrain...
#
# From chat:
#
# **lam**: controls smoothness [1 – 50]
# - higher → smoother, less structure
# - lower → sharper, more detail (risk of noise)
#
# **paraDX**: horizontal cell size (m) [0.25 – 1 × electrode spacing]
# - smaller → higher resolution
# - larger → faster, smoother
# - *note*: don’t go smaller than electrode spacing
#
# **paraMaxCellSize**: max cell size at depth and controls mesh coarsening downward [5 – 20]
#
# **paraDepth**: max inversion depth (m) [0.2 – 0.3 × line length]
#
# **quality**: data quality [10 - 40]

# %%
# initializing ERT manager
mgr = ert.ERTManager(data)

mgr.setMesh(mesh)

os.chdir(r'C:\Users\sydne\git\erth370\erth370-w2026-sydpas\pygimex\ert\extra_files\line02')
print(f'Directory: {os.getcwd()}')

# mod = mgr.invert(data, lam=10, verbose=True,
#                  paraDX=0.3, paraMaxCellSize=10, paraDepth=30, quality=32)
mod = mgr.invert(data, lam=10, verbose=True, quality=32)

os.chdir(r'C:\Users\sydne\git\erth370\erth370-w2026-sydpas')
print(f'Directory: {os.getcwd()}')

fig, ax = plt.subplots(figsize=(10, 8))
ax, cb = mgr.showResult(ax=ax, cMap='viridis', logScale=True)

ax.set_title("Inversion Result with Resistivity Data")
ax.set_xlabel("Distance [m]")
ax.set_ylabel("Elevation [m]")

fig.savefig(r"figures\line02\new_ball_asf1\5inversion_result.png", dpi=300, bbox_inches="tight")
# Out:
# 03/03/26 - 14:50:12 - pyGIMLi - INFO - Found 1 regions.
# 03/03/26 - 14:50:12 - pyGIMLi - INFO - Creating forward mesh from region infos.
# Directory: C:\Users\sydne\git\erth370\erth370-w2026-sydpas\pygimex\ert\extra_files\line02
# 03/03/26 - 14:50:12 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 03/03/26 - 14:50:12 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 7731 Cells: 15064 Boundaries: 11496
# 03/03/26 - 14:50:12 - pyGIMLi - INFO - Use median(data values)=697.9487376121358
# 03/03/26 - 14:50:12 - pyGIMLi - INFO - Created startmodel from forward operator:3766, min/max=697.948738/697.948738
# 03/03/26 - 14:50:12 - pyGIMLi - INFO - Starting inversion.
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x000001F00BA59580>
# Data transformation: Logarithmic LU transform, lower bound 0.0, upper bound 0.0
# Model transformation: Logarithmic transform
# min/max (data): 21.99/4215
# min/max (error): 3%/3.64%
# min/max (start model): 698/698
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² = 1311.18
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² =  274.15 (dPhi = 78.44%) lam: 10.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² =  111.00 (dPhi = 58.06%) lam: 10.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... chi² =   59.64 (dPhi = 42.89%) lam: 10.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... chi² =   35.31 (dPhi = 37.99%) lam: 10.0
# --------------------------------------------------------------------------------
# inv.iter 5 ... chi² =   17.03 (dPhi = 40.07%) lam: 10.0
# --------------------------------------------------------------------------------
# inv.iter 6 ... chi² =   17.13 (dPhi = 0.22%) lam: 10.0
# ################################################################################
# #                Abort criterion reached: dPhi = 0.22 (< 2.0%)                 #
# ################################################################################
# Directory: C:\Users\sydne\git\erth370\erth370-w2026-sydpas
# C:\Users\sydne\AppData\Local\Temp\ipykernel_80800\3843719354.py:16: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=(10, 8))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ax = mgr.showResultAndFit(cMap = 'viridis')
fig = ax.figure

fig.savefig(r'figures\line02\new_ball_asf1\6inver_data_response.png',dpi=300,bbox_inches="tight")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# from chat:
#
# **cov**: computes coverage for each cell.
# - high value → cell is well constrained by data.
#
# **model**: resistivity value for each cell in the mesh.
#
# **model_mask**: if a cell has zero coverage, replace its resistivity with NaN.
#
# dont need both cov and mask.

# %%
cov = mgr.standardizedCoverage()
model = mgr.inv.model
model_mask = model.copy()
model_mask[cov == 0] = np.nan 

print(np.nanmin(model_mask))
print(np.nanmax(model_mask))

fig, ax = plt.subplots(figsize=(10, 8))
ax, cb = mgr.showResult(model=model_mask, ax=ax, cMap='viridis', logScale=False)
# Out:
# 3.523910921408698
# 12447.568709226025
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# now we plot the points that are valid

# %%
# mask of valid points
valid_mask = ~np.isnan(model_mask)

print(valid_mask)

# indices
values_MM = model_mask[valid_mask]

# get mesh coordinates of elec and z cells
coords = np.array(mesh.cellCenters())

x_valid = coords[valid_mask, 0]
z_valid = coords[valid_mask, 1]

fig, ax = plt.subplots(figsize=(10, 4))

ax.scatter(x_valid, z_valid, c=values_MM, cmap='viridis', s=10)
ax.set_xlabel("X [m]")
ax.set_ylabel("Z [m]")
ax.set_title("Valid Mesh Values")
plt.colorbar(ax.collections[0], ax=ax, label='Resistivity')

fig.savefig(r"figures\line02\new_ball_asf1\7mesh_pnts.png",dpi=300,bbox_inches="tight")

plt.show()
# Out:
# [False False False ... False False False]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# now this is for after we invert that we can constrain manually for testing. better to constrain at low values!

# %%
# lists to store clicked points
x_line = []
z_line = []

fig, ax = plt.subplots(figsize=(10,8))

ax, cb = mgr.showResult(model=model_mask, ax=ax, cMap='viridis', logScale=False)
# ax, cb = mgr.showResult(mod, ax=ax, cMin=50, cMax=4000, cMap='viridis',logScale=True)

ax.set_xlabel("Distance [m]")
ax.set_ylabel("Elevation [m]")
ax.set_title('TBD Constrained Resistivity')

# connect click handler to the SAME figure
cid = fig.canvas.mpl_connect('button_press_event', onclick)

fig.savefig(r"figures/line02/new_ball_asf1/8constr_inver.png", dpi=300, bbox_inches='tight')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# now re inverting with the resist contrains

# %%
fig.canvas.mpl_disconnect(cid)

plt.ion()

print(x_line)
print(z_line)
# Out:
# [17.785907853472555, 20.452637242929878, 24.702809102407596, 29.218616703102672, 35.062603009884526, 44.89112543492675, 50.2038402592739, 55.51655508362106, 66.93889195596742, 70.92342807422779, 77.82995734587908, 82.0801292053568, 84.73648661753037, 90.31483718309488, 95.89318774865937, 102.26844553787596, 105.72171017370161, 108.64370332709254, 126.97256947109018, 134.4103702251762, 141.58253523804484, 149.81724321578292, 156.98940822865157, 162.83339453543343]
# [64.75303453923215, 63.25727246379276, 60.60091505161921, 58.47582912188034, 57.67892189822827, 55.55383596848941, 56.8820146745762, 58.210193380662986, 51.569299850229044, 51.834935591446396, 51.834935591446396, 52.63184281509848, 56.61637893335883, 56.08510745092413, 51.569299850229044, 48.91294243805547, 50.77239262657697, 49.70984966170754, 40.14696297788268, 37.756241306926455, 36.959334083274385, 38.02187704814382, 38.02187704814382, 38.553148530578525]

# %% [markdown]
# We now want to include this line into the inversion mesh.
# Therefore we generate the geometry of the inversion, a polygone from the line
# and merge both objects before we send it to the mesh generation.
#
# For line = mt.createPolygon...
# - if 1: boundary contraint
# - if >1: internal structure (bedrock)
# - to clip for fault:
#     xmin, xmax = 0, 200
#     xz_clip = xz[(xz[:, 0] >= xmin) & (xz[:, 0] <= xmax)]
#     line = mt.createPolygon(xz_clip, marker=2)

# %%
xz = np.column_stack([x_line, z_line])

# make sure line in domain
xmin, xmax = data.sensorPositions()[:,0].min(), data.sensorPositions()[:,0].max()
xz = xz[(xz[:, 0] >= xmin) & (xz[:, 0] <= xmax)]
xz[:, 1] -= 0.5  # ensure not to hit the surface

# build a piecewise linear complex (PLC) for meshing based on electrode pos
plc = mt.createParaMeshPLC(data, paraDepth=30, boundary=1)

# turn the xz points into polyline from topography or structure
line = mt.createPolygon(xz, marker=2)

plc += line

# generates the finite element mesh
mesh = mt.createMesh(plc, quality=34.3)  

ax, _ = pg.show(mesh, markers=True, showMesh=True)
ax.set_title('Finite Element Mesh with Constraint Added', fontsize=14);
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# We see the outer boundaries have markers of -1 (homogeneous Neumann, no-flow)
# and -2 (mixed) important to define the boundary conditions of the forward
# problem. The interface between the inversion domain (yellow) and the outer
# region (blue) and the added interface are >0 and do not affect the forward.
# We now use the generated mesh in a new ERT manager by setting it.

# %%
mgr = ert.Manager(data)
mgr.setMesh(mesh)
mod = mgr.invert(verbose=True)

fig, ax1 = plt.subplots(figsize=(10,8))

ax, cb = mgr.showResult(mod, ax=ax1, cMin=200, cMax=3000, cMap='viridis',logScale=True)

ax1.set_title('Re-Inverted Resistivity Model with Constraint Added', fontsize=14)

fig.savefig(r'figures/line02/new_ball_asf1/9re_re.png', dpi=300, bbox_inches='tight')
# Out:
# 02/03/26 - 20:27:28 - pyGIMLi - INFO - Found 2 regions.
# 02/03/26 - 20:27:28 - pyGIMLi - INFO - Region with smallest marker set to background (marker=1)
# 02/03/26 - 20:27:28 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 02/03/26 - 20:27:29 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 02/03/26 - 20:27:31 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 14749 Cells: 29056 Boundaries: 22012
# 02/03/26 - 20:27:31 - pyGIMLi - INFO - Use median(data values)=697.9487376121374
# 02/03/26 - 20:27:31 - pyGIMLi - INFO - Created startmodel from forward operator:2698, min/max=697.948738/697.948738
# 02/03/26 - 20:27:31 - pyGIMLi - INFO - Starting inversion.
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x00000248A3190B80>
# Data transformation: Logarithmic LU transform, lower bound 0.0, upper bound 0.0
# Model transformation: Logarithmic transform
# min/max (data): 21.99/4215
# min/max (error): 3%/3.64%
# min/max (start model): 698/698
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² =  925.40
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² =  233.94 (dPhi = 74.09%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² =   52.16 (dPhi = 75.45%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... chi² =   19.40 (dPhi = 56.94%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... chi² =   10.30 (dPhi = 35.72%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 5 ... chi² =    5.08 (dPhi = 31.12%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 6 ... chi² =    4.30 (dPhi = 6.71%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 7 ... chi² =    3.73 (dPhi = 4.44%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 8 ... chi² =    3.07 (dPhi = 6.08%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 9 ... chi² =    2.76 (dPhi = 2.67%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 10 ... chi² =    3.10 (dPhi = -3.80%) lam: 20.0
# ################################################################################
# #                Abort criterion reached: dPhi = -3.8 (< 2.0%)                 #
# ################################################################################
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pygimli as pg
import pygimli.meshtools as mt
from pygimli.physics import ert
import pandas as pd
import scipy as sp
import os

# %%
os.chdir(r'C:\Users\sydne\git\erth370\erth370-w2026-sydpas')
print(f'Directory: {os.getcwd()}')  # shows current working directory
os.makedirs(r"figures/line05/final_jacobian", exist_ok=True)

filename = r'data\line01\og_fromtomsnotes_mytopo\project_6\Dipole-Dipole_1-2018-06-12-181644.dat'
data = ert.load(filename)
print(data)

xs = np.array([s.x() for s in data.sensors()])  # an array of all elec x-positions along line
data_min = xs.min(); data_max = xs.max()
print(data_min, data_max)
# Out:
# 22/04/26 - 14:56:18 - pyGIMLi - INFO - could not read unified data format for ERT ... try res2dinv
# Directory: C:\Users\sydne\git\erth370\erth370-w2026-sydpas
# Data: Sensors: 81 data: 1469, nonzero entries: ['a', 'b', 'm', 'n', 'r', 'valid']
# 0.0 200.0

# %%
topo = []

topo_file = r'data\line01\og_fromtomsnotes_mytopo\200_line01_mytopo.txt'

with open(topo_file) as f: 
    next(f)  # skip header line
    for line in f:
        line = line.strip()
        parts = line.split()  # split using whitespace
        if len(parts) == 2:  # if data has 2 columns it is topo data so add to the list
            topo.append([float(parts[0]), float(parts[1])])

topo = np.array(topo)  # convert to numpy array

topo = topo[np.argsort(topo[:,0])]

x_elec = pg.x(data)  # get x pos of all electrodes
z_elec = np.interp(x_elec, topo[:,0], topo[:,1])  # interpolate topo at each electrode

x_elec = np.array(pg.x(data))  # convert RVector to numpy

# now we ensure topo covers all electrodes at both ends
if topo[0,0] > x_elec.min():  # if topo is to the right of (after) electrode
    topo = np.vstack(([x_elec.min(), topo[0,1]], topo))
if topo[-1,0] < x_elec.max():  # if topo is to the left of (before) electrode
    topo = np.vstack((topo, [x_elec.max(), topo[-1,1]]))

# second interp of topo at electrode positions
z_interp = np.interp(x_elec, topo[:,0], topo[:,1])

# set electrode positions in data
data.setSensorPositions(pg.PosVector(np.c_[x_elec, z_interp]))  # combine into 2D array, convert to gimli pos vector, and update elec pos in ERT dataset

# ensure arrays
x_elec = np.array(pg.x(data))
z_interp = np.array(z_interp)

plt.figure(figsize=(10,4))
plt.plot(x_elec, z_interp, 'r*')
plt.xlabel('Electrode Location [m]')
plt.ylabel('Elevation [m]')
plt.title('Topography')
# plt.show()
plt.close()

# %%
def build_electrode_scheme(type, sensors_x, sensors_y):

    elecs = np.c_[sensors_x, sensors_y]   # combine x and z

    # remove the two bad electrodes
    elecs = elecs[2:]

    scheme = ert.createData(elecs=elecs, schemeName=type)

    return scheme

# %%
nelecs = 81  # from data file
pos = np.zeros((nelecs, 2))
pos[:, 0] = np.linspace(5, 25, nelecs)

#comment one or the other out
# scheme = build_electrode_scheme('gr', x_elec, z_interp)
# scheme["k"] = ert.createGeometricFactors(scheme)

scheme = build_electrode_scheme('dd', x_elec, z_interp)
scheme["k"] = ert.createGeometricFactors(scheme)
# Out:
# 22/04/26 - 14:56:30 - pyGIMLi - INFO - Cache c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\physics\ert\ert.py:createGeometricFactors restored (0.0s x 3): C:\Users\sydne\AppData\Roaming\pygimli\Cache\12654988499670312063
# 22/04/26 - 14:56:30 - pyGIMLi - INFO - Cache c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\physics\ert\ert.py:createGeometricFactors restored (0.0s x 3): C:\Users\sydne\AppData\Roaming\pygimli\Cache\14126084441210609127

# %% [markdown]
# > from claude
#
# **world_topo**: Creates the outer boundary of the mesh as a closed polygon
# - It's built by taking your topography and closing it off at the bottom
# - Shape is essentially: left edge → topography surface → right edge → flat bottom
#
# **topo_line**: Creates just the surface topography line as an open polygon (not closed)
# - marker=-1 flags it as a boundary constraint, forcing the mesher to respect the surface shape
# - This is what makes the mesh surface follow your actual topography rather than being flat
#
# **geom**: Merges both into a single PLC (Piecewise Linear Complex)
# - This is the final geometry handed to createMesh

# %%
world_bottom = topo[:,1].min()

world_topo = mt.createPolygon(
    [[topo[0,0], world_bottom]] + topo.tolist() + [[topo[-1,0], world_bottom]],
    isClosed=True,marker=1)

top_mean = topo[:,1].mean()

topo_line = mt.createPolygon(
    topo,
    isClosed=False,
    marker=-1
)

# topo nodes are created automatically here
geom = mt.mergePLC([world_topo, topo_line])

fig, ax = plt.subplots(figsize=(14,8))

pg.show(geom, ax=ax)

ax.set_xlabel('Distance (m)')
ax.set_ylabel('Elevation (m)')
ax.set_title('World Topography and Polygon Base')

fig.savefig(r"figures/line05/final_jacobian/1world_topo.png", dpi=400, bbox_inches='tight')

# %% [markdown]
# > from claude
#
# **mt.createMesh()**: with a PLC geometry uses Triangle (a Delaunay triangulator)
# - https://www.pygimli.org/pygimliapi/_generated/pygimli.meshtools.html
#     - https://www.pygimli.org/_modules/pygimli/meshtools/mesh.html#createMesh
#     - https://www.pygimli.org/glossary.html#term-Triangle
# - https://www.cs.cmu.edu/~quake/triangle.html
#     - https://www.cs.cmu.edu/~quake/triangle.defs.html
#
# Mesh geometry → from topography points
#
# Electrode positions → constrain where current is injected/measured
#
# Starting model → uniform resistivity (1 Ohm·m) assigned to all mesh cells.
#
# Jacobian then tells you how sensitive your measurements are to each of those mesh cells.

# %%
area_val = 1
qualll = 32

mesh = mt.createMesh(geom, quality=qualll, area=area_val, smooth=[1,10])

# %%
nodes = np.array([[mesh.node(i).x(), mesh.node(i).y()] for i in range(mesh.nodeCount())])
cells = np.array([[mesh.cell(i).node(j).id() for j in range(mesh.cell(i).nodeCount())] for i in range(mesh.cellCount())])

print(f'Number of nodes: {mesh.nodeCount()}')
print(f'Number of cells: {mesh.cellCount()}')

df = pd.DataFrame(cells[:500], columns=['node_0', 'node_1', 'node_2'])
for col in ['node_0', 'node_1', 'node_2']:
    df[f'{col}_x'] = df[col].apply(lambda i: nodes[i][0])
    df[f'{col}_y'] = df[col].apply(lambda i: nodes[i][1])
# print(df.to_string())

rows = []
for _, r in df.iterrows():
    rows.append((r.node_0_x, r.node_0_y))
    rows.append((r.node_1_x, r.node_1_y))
    rows.append((r.node_2_x, r.node_2_y))
    rows.append((r.node_0_x, r.node_0_y))  # close the triangle
    rows.append((None, None))               # blank row = break between triangles

plot_df = pd.DataFrame(rows, columns=['x', 'y'])
# print(plot_df.to_string())
# Out:
# Number of nodes: 3446
# Number of cells: 6454

# %%
fig, ax = plt.subplots(figsize=(16,4))
pg.show(mesh, ax=ax, showMesh=True)

ax.set_xlabel('Distance (m)')
ax.set_ylabel('Elevation (m)')
ax.set_title(f'Base Mesh with an Area of {area_val} and Quality of {qualll}')

fig.savefig(r"figures/line05/final_jacobian/2mesh.png", dpi=400, bbox_inches='tight')

# %% [markdown]
# > for trouble shooting...
#
# **this is common error**:
#
# mesh cell count: 20450
#
# mesh node count: 10479
#
# Cell for sensor RVector3: (5.0, 86.7172, 0.0): None
#
# sensor outside mesh: RVector3: (5.0, 86.7172, 0.0)
#
# Cell for sensor RVector3: (5.25, 82.72896607105152, 0.0): None
#
# sensor outside mesh: RVector3: (5.25, 82.72896607105152, 0.0)
#
# Cell for sensor RVector3: (5.5, 79.60510881330036, 0.0): <pgcore._pygimli_.Triangle object at 0x00000182585BBDF0> ID: 16781, Marker: 1, Size: 1.8418247009920454 8209 RVector3: (4.679328259648554, 80.14537369749408, 0.0) 8588 RVector3: (5.268856563298982, 77.93652249843612, 0.0) 7790 RVector3: (6.623138830301008, 79.1107517735486, 0.0)
#
# ...and we DON'T want it to say *sensor outside mesh*.

# %%
for n in mesh.nodes():
    if len(n.cellSet()) == 0:
        print("isolated node:", n.id(), n.pos())

for p in scheme.sensorPositions():
    cell = mesh.findCell(p)
    print(f'Cell for sensor {p}: {cell}')
    if mesh.findCell(p) is None:
        print("sensor outside mesh:", p)
# Out:
# Cell for sensor RVector3: (5.0, 30.868800473286125, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB680>	ID: 6307, Marker: 1, Size: 0.711551288586932
# 	3366 RVector3: (4.9129482675, 30.884475000000002, 0.0)
# 	3368 RVector3: (6.010807502368249, 29.817803589711858, 0.0)
# 	2 RVector3: (6.55059769, 30.5896, 0.0)
#
# Cell for sensor RVector3: (7.5, 30.525492587946907, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB760>	ID: 6252, Marker: 1, Size: 0.45181757528072963
# 	2 RVector3: (6.55059769, 30.5896, 0.0)
# 	3359 RVector3: (6.922547418017596, 29.721489478702264, 0.0)
# 	3358 RVector3: (7.6225318665625, 30.51721875, 0.0)
#
# Cell for sensor RVector3: (10.0, 30.356682665699363, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB680>	ID: 6253, Marker: 1, Size: 0.49961307290153584
# 	3309 RVector3: (10.048325552622186, 29.4212483530027, 0.0)
# 	3192 RVector3: (10.83833439625, 30.300075000000003, 0.0)
# 	3332 RVector3: (9.766400219687501, 30.372456250000003, 0.0)
#
# Cell for sensor RVector3: (12.5, 30.18787274345182, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 5988, Marker: 1, Size: 0.41694201350026905
# 	3254 RVector3: (13.143222325481313, 29.366515161804227, 0.0)
# 	3194 RVector3: (12.982202749374999, 30.155312500000004, 0.0)
# 	3255 RVector3: (11.910268572812498, 30.227693750000004, 0.0)
#
# Cell for sensor RVector3: (15.0, 30.019062821204276, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB760>	ID: 6112, Marker: 1, Size: 0.5474892902853541
# 	3252 RVector3: (14.275881848137812, 29.04646018721181, 0.0)
# 	2901 RVector3: (15.1260711025, 30.010550000000002, 0.0)
# 	3253 RVector3: (14.054136925937499, 30.08293125, 0.0)
#
# Cell for sensor RVector3: (17.5, 29.850252898956732, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 5473, Marker: 1, Size: 1.1684243160698398
# 	2932 RVector3: (17.269939455625, 29.865787500000003, 0.0)
# 	3246 RVector3: (18.185995258056415, 28.71391679084962, 0.0)
# 	2920 RVector3: (19.41380780875, 29.721025, 0.0)
#
# Cell for sensor RVector3: (20.0, 29.68144297670919, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB760>	ID: 6083, Marker: 1, Size: 0.9613155827513227
# 	3163 RVector3: (21.557676161875, 29.5762625, 0.0)
# 	2920 RVector3: (19.41380780875, 29.721025, 0.0)
# 	3237 RVector3: (20.639436541066654, 28.74146100680821, 0.0)
#
# Cell for sensor RVector3: (22.5, 29.512633054461645, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 6096, Marker: 1, Size: 0.5601933293641969
# 	3163 RVector3: (21.557676161875, 29.5762625, 0.0)
# 	3238 RVector3: (21.872876314562422, 28.509777948265544, 0.0)
# 	3244 RVector3: (22.6296103384375, 29.50388125, 0.0)
#
# Cell for sensor RVector3: (25.0, 29.3438231322141, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB760>	ID: 5749, Marker: 1, Size: 0.46738779676531506
# 	3066 RVector3: (25.722065839008373, 28.423020677061853, 0.0)
# 	2522 RVector3: (25.845412868124995, 29.2867375, 0.0)
# 	3067 RVector3: (24.773478691562495, 29.35911875, 0.0)
#
# Cell for sensor RVector3: (27.5, 29.175013209966558, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB680>	ID: 4688, Marker: 1, Size: 0.4987315607733169
# 	3065 RVector3: (27.452952271770783, 28.247663592888852, 0.0)
# 	2238 RVector3: (27.989281221249996, 29.141975000000002, 0.0)
# 	2846 RVector3: (26.917347044687496, 29.21435625, 0.0)
#
# Cell for sensor RVector3: (30.0, 29.006203287719014, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB760>	ID: 4673, Marker: 1, Size: 0.987033767765021
# 	2242 RVector3: (30.133149574374997, 28.997212500000003, 0.0)
# 	2238 RVector3: (27.989281221249996, 29.141975000000002, 0.0)
# 	2509 RVector3: (29.000511382285115, 28.152895731850904, 0.0)
#
# Cell for sensor RVector3: (32.5, 28.83739336547147, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB680>	ID: 4135, Marker: 1, Size: 0.4880576470952801
# 	2233 RVector3: (33.3489521040625, 28.780068749999998, 0.0)
# 	2192 RVector3: (32.2770179275, 28.85245, 0.0)
# 	2236 RVector3: (32.760271792685124, 27.90920755552231, 0.0)
#
# Cell for sensor RVector3: (35.0, 28.668583443223927, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB760>	ID: 4079, Marker: 1, Size: 0.45258666622261473
# 	2215 RVector3: (34.420886280625, 28.7076875, 0.0)
# 	2231 RVector3: (34.16536019901866, 27.88051167648593, 0.0)
# 	2378 RVector3: (35.4928204571875, 28.63530625, 0.0)
#
# Cell for sensor RVector3: (37.5, 28.499773520976383, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 4095, Marker: 1, Size: 0.6247692676902346
# 	2205 RVector3: (36.56475463375, 28.562925, 0.0)
# 	2213 RVector3: (36.87904173850067, 27.37601720594011, 0.0)
# 	2212 RVector3: (37.6366888103125, 28.49054375, 0.0)
#
# Cell for sensor RVector3: (40.0, 28.33096359872884, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB760>	ID: 4092, Marker: 1, Size: 1.1679738610125439
# 	3 RVector3: (40.85249134, 28.2734, 0.0)
# 	2208 RVector3: (38.708622986875, 28.4181625, 0.0)
# 	2209 RVector3: (39.7587171447805, 27.257661215519395, 0.0)
#
# Cell for sensor RVector3: (42.5, 27.918100579230956, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 4958, Marker: 1, Size: 0.6363571342125124
# 	2656 RVector3: (42.249353054030685, 26.89968514072594, 0.0)
# 	2195 RVector3: (43.225918535000005, 27.76155, 0.0)
# 	2658 RVector3: (42.0392049375, 28.017474999999997, 0.0)
#
# Cell for sensor RVector3: (45.0, 27.37895406456401, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB760>	ID: 4405, Marker: 1, Size: 0.6816782913453241
# 	2373 RVector3: (44.60949823184007, 26.314318570089256, 0.0)
# 	4 RVector3: (45.59934573, 27.2497, 0.0)
# 	2372 RVector3: (44.41263213250001, 27.505625, 0.0)
#
# Cell for sensor RVector3: (47.5, 26.809753371992954, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 3899, Marker: 1, Size: 0.5573784897257594
# 	2107 RVector3: (47.944778420000006, 26.7068, 0.0)
# 	2524 RVector3: (46.77206207500001, 26.97825, 0.0)
# 	2527 RVector3: (46.916625809016274, 25.994210841707005, 0.0)
#
# Cell for sensor RVector3: (50.0, 26.231075499126774, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB760>	ID: 5328, Marker: 1, Size: 0.6617518012959401
# 	5 RVector3: (50.29021111, 26.1639, 0.0)
# 	2852 RVector3: (49.117494765000004, 26.43535, 0.0)
# 	2851 RVector3: (49.588286057237184, 25.19779591877871, 0.0)
#
# Cell for sensor RVector3: (52.5, 25.90500842934847, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 4824, Marker: 1, Size: 0.8677642378068222
# 	2294 RVector3: (51.96840240561358, 24.60426678623832, 0.0)
# 	2291 RVector3: (52.836800455, 25.86555, 0.0)
# 	2586 RVector3: (51.5635057825, 26.014725, 0.0)
#
# Cell for sensor RVector3: (55.0, 25.612116683192202, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB760>	ID: 3610, Marker: 1, Size: 0.7943228798536257
# 	2292 RVector3: (54.501493887460526, 24.422854572014103, 0.0)
# 	6 RVector3: (55.3833898, 25.5672, 0.0)
# 	2285 RVector3: (54.1100951275, 25.716375, 0.0)
#
# Cell for sensor RVector3: (57.5, 25.309399499779897, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 4233, Marker: 1, Size: 0.6296210183300872
# 	2281 RVector3: (56.608566465, 25.417975, 0.0)
# 	2283 RVector3: (57.049195521893935, 24.336502469934164, 0.0)
# 	2155 RVector3: (57.83374313, 25.26875, 0.0)
#
# Cell for sensor RVector3: (60.0, 25.004902596878143, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB760>	ID: 4220, Marker: 1, Size: 0.7931255064092535
# 	2275 RVector3: (59.81332315398058, 23.732927538104672, 0.0)
# 	7 RVector3: (60.28409646, 24.9703, 0.0)
# 	2584 RVector3: (59.058919795, 25.119525000000003, 0.0)
#
# Cell for sensor RVector3: (62.5, 24.71630775565221, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 3377, Marker: 1, Size: 0.573751014935111
# 	2582 RVector3: (61.98842347890139, 23.84851892919405, 0.0)
# 	1840 RVector3: (62.76136033, 24.68635, 0.0)
# 	2267 RVector3: (61.522728395, 24.828325, 0.0)
#
# Cell for sensor RVector3: (65.0, 24.429751685224392, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB760>	ID: 3380, Marker: 1, Size: 0.5612441641301612
# 	1841 RVector3: (63.999992265, 24.544375000000002, 0.0)
# 	1842 RVector3: (64.69191916045479, 23.55883230991708, 0.0)
# 	8 RVector3: (65.2386242, 24.4024, 0.0)
#
# Cell for sensor RVector3: (67.5, 24.010445573031046, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 3370, Marker: 1, Size: 0.6403305576936363
# 	1837 RVector3: (66.89175523593937, 23.100563332324217, 0.0)
# 	1524 RVector3: (67.7613322, 23.96515, 0.0)
# 	1835 RVector3: (66.4999782, 24.183775, 0.0)
#
# Cell for sensor RVector3: (70.0, 23.5771314518565, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB760>	ID: 2792, Marker: 1, Size: 0.5412764376836596
# 	1845 RVector3: (69.22256241491966, 22.853634651331717, 0.0)
# 	9 RVector3: (70.2840402, 23.5279, 0.0)
# 	1533 RVector3: (69.02268620000001, 23.746525, 0.0)
#
# Cell for sensor RVector3: (72.5, 23.03565613708456, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 2783, Marker: 1, Size: 0.7798697324071372
# 	1516 RVector3: (71.82214259540933, 21.9472770995487, 0.0)
# 	1503 RVector3: (72.8018701, 22.968600000000002, 0.0)
# 	1536 RVector3: (71.54295515000001, 23.24825, 0.0)
#
# Cell for sensor RVector3: (75.0, 22.480316795058318, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB760>	ID: 2727, Marker: 1, Size: 0.5468500986419187
# 	10 RVector3: (75.3197, 22.4093, 0.0)
# 	1504 RVector3: (74.06078504999999, 22.688950000000002, 0.0)
# 	2136 RVector3: (74.6558648226622, 21.687997349696804, 0.0)
#
# Cell for sensor RVector3: (77.5, 22.023181746348346, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 2567, Marker: 1, Size: 0.5560587800062922
# 	1420 RVector3: (77.17247283565435, 21.17514944114067, 0.0)
# 	1414 RVector3: (77.774609645, 21.97455, 0.0)
# 	1421 RVector3: (76.5471548225, 22.191925, 0.0)
#
# Cell for sensor RVector3: (80.0, 21.580446510771072, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB760>	ID: 2556, Marker: 1, Size: 0.7145560645481526
# 	1413 RVector3: (79.4917954592579, 20.50615754886308, 0.0)
# 	11 RVector3: (80.22951929, 21.5398, 0.0)
# 	1415 RVector3: (79.00206446749999, 21.757175, 0.0)
#
# Cell for sensor RVector3: (82.5, 21.239896202901626, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 2538, Marker: 1, Size: 0.5558022164094176
# 	1403 RVector3: (81.99112934806378, 20.409893141582582, 0.0)
# 	1388 RVector3: (82.707408345, 21.2125, 0.0)
# 	1405 RVector3: (81.46846381750001, 21.37615, 0.0)
#
# Cell for sensor RVector3: (85.0, 20.90967560712923, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB760>	ID: 6438, Marker: 1, Size: 0.6785616189174014
# 	1390 RVector3: (84.53980485361615, 19.87507536984856, 0.0)
# 	12 RVector3: (85.1852974, 20.8852, 0.0)
# 	3437 RVector3: (83.9463528725, 21.04885, 0.0)
#
# Cell for sensor RVector3: (87.5, 20.5824746452956, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 2525, Marker: 1, Size: 0.6917792696267135
# 	1408 RVector3: (86.83129620745366, 19.548126752854895, 0.0)
# 	1386 RVector3: (87.65196577500001, 20.5626, 0.0)
# 	1398 RVector3: (86.4186315875, 20.7239, 0.0)
#
# Cell for sensor RVector3: (90.0, 20.2555154122775, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB760>	ID: 2464, Marker: 1, Size: 0.5838833613893801
# 	13 RVector3: (90.11863415, 20.24, 0.0)
# 	1395 RVector3: (88.8852999625, 20.4013, 0.0)
# 	1399 RVector3: (89.20496813533748, 19.412655388170133, 0.0)
#
# Cell for sensor RVector3: (92.5, 19.897067743175633, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 2445, Marker: 1, Size: 0.6095977609914695
# 	1356 RVector3: (92.02624452198975, 18.96587720689813, 0.0)
# 	1323 RVector3: (92.558453895, 19.88865, 0.0)
# 	1358 RVector3: (91.3385440225, 20.064324999999997, 0.0)
#
# Cell for sensor RVector3: (95.0, 19.536968050710325, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB760>	ID: 2380, Marker: 1, Size: 0.70599409922537
# 	14 RVector3: (94.99827364, 19.5373, 0.0)
# 	1318 RVector3: (95.5874841026723, 18.29428061447001, 0.0)
# 	1322 RVector3: (96.24812559, 19.296974999999996, 0.0)
#
# Cell for sensor RVector3: (97.5, 19.056261115780952, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 2390, Marker: 1, Size: 0.7140110431652369
# 	1587 RVector3: (98.74782948999999, 18.816325, 0.0)
# 	1304 RVector3: (97.49797754, 19.056649999999998, 0.0)
# 	1328 RVector3: (97.71541808503503, 17.87228693578585, 0.0)
#
# Cell for sensor RVector3: (100.0, 18.575478898850857, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB760>	ID: 2882, Marker: 1, Size: 0.6819492890240665
# 	15 RVector3: (99.99768144, 18.576, 0.0)
# 	1585 RVector3: (100.26707724629796, 17.41348806405137, 0.0)
# 	1584 RVector3: (101.23537862999999, 18.297825000000003, 0.0)
#
# Cell for sensor RVector3: (102.5, 18.01359873493128, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 3419, Marker: 1, Size: 0.5772067480359094
# 	1582 RVector3: (102.47307581999999, 18.019650000000002, 0.0)
# 	1861 RVector3: (103.80885170695097, 16.78672084272818, 0.0)
# 	1859 RVector3: (103.71077301, 17.741475, 0.0)
#
# Cell for sensor RVector3: (105.0, 17.45642430740464, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB760>	ID: 2217, Marker: 1, Size: 0.5633902416046545
# 	1241 RVector3: (106.21766185, 17.293950000000002, 0.0)
# 	16 RVector3: (104.9484702, 17.4633, 0.0)
# 	1855 RVector3: (105.06631435274237, 16.55978208725906, 0.0)
#
# Cell for sensor RVector3: (107.5, 17.122845844293888, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 2206, Marker: 1, Size: 0.6892091656762338
# 	1233 RVector3: (107.4868535, 17.1246, 0.0)
# 	1237 RVector3: (108.00145494730252, 15.969875978255027, 0.0)
# 	1235 RVector3: (108.75604515, 16.95525, 0.0)
#
# Cell for sensor RVector3: (110.0, 16.789267381183134, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB760>	ID: 2209, Marker: 1, Size: 0.7131237981249544
# 	1232 RVector3: (109.1985696663415, 15.772458478252796, 0.0)
# 	17 RVector3: (110.0252368, 16.7859, 0.0)
# 	1235 RVector3: (108.75604515, 16.95525, 0.0)
#
# Cell for sensor RVector3: (112.5, 16.40334892675827, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 2199, Marker: 1, Size: 0.9239809676379946
# 	1023 RVector3: (111.80172835400406, 15.048430442907069, 0.0)
# 	1017 RVector3: (112.5517459, 16.39535, 0.0)
# 	1229 RVector3: (111.28849135, 16.590625000000003, 0.0)
#
# Cell for sensor RVector3: (115.0, 16.016896726764212, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB760>	ID: 1821, Marker: 1, Size: 0.5128163106488992
# 	18 RVector3: (115.078255, 16.0048, 0.0)
# 	1020 RVector3: (113.81500045, 16.200075, 0.0)
# 	1032 RVector3: (114.32859361954753, 15.308786282709256, 0.0)
#
# Cell for sensor RVector3: (117.5, 15.697371228563158, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 1460, Marker: 1, Size: 0.8327221972894009
# 	814 RVector3: (117.53640335, 15.69275, 0.0)
# 	980 RVector3: (116.307329175, 15.848774999999998, 0.0)
# 	981 RVector3: (116.60940603806304, 14.455388032823489, 0.0)
#
# Cell for sensor RVector3: (120.0, 15.379532399967195, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB760>	ID: 1373, Marker: 1, Size: 0.46307680742536167
# 	19 RVector3: (119.9945517, 15.3807, 0.0)
# 	960 RVector3: (119.82658629101456, 14.66651273903594, 0.0)
# 	798 RVector3: (121.22912170000001, 15.116124999999998, 0.0)
#
# Cell for sensor RVector3: (122.5, 14.843768935765084, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB680>	ID: 1293, Marker: 1, Size: 0.7056774573571424
# 	781 RVector3: (122.4636917, 14.85155, 0.0)
# 	795 RVector3: (122.67837541446156, 13.662346586286754, 0.0)
# 	3432 RVector3: (123.69826169999999, 14.586975, 0.0)
#
# Cell for sensor RVector3: (125.0, 14.314554471563934, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB760>	ID: 1335, Marker: 1, Size: 0.6389780920640821
# 	776 RVector3: (125.97132322499999, 14.2011, 0.0)
# 	20 RVector3: (124.9328317, 14.3224, 0.0)
# 	778 RVector3: (125.53650243506708, 13.021299883374779, 0.0)
#
# Cell for sensor RVector3: (127.5, 14.022544385107041, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB680>	ID: 1319, Marker: 1, Size: 1.015484864211
# 	21 RVector3: (129.0867978, 13.8372, 0.0)
# 	766 RVector3: (127.00981475, 14.079799999999999, 0.0)
# 	768 RVector3: (127.75382954925239, 13.015049992184272, 0.0)
#
# Cell for sensor RVector3: (130.0, 13.72807949980661, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB760>	ID: 1786, Marker: 1, Size: 0.6172015849430981
# 	21 RVector3: (129.0867978, 13.8372, 0.0)
# 	1014 RVector3: (129.72206350417216, 12.751525221883602, 0.0)
# 	760 RVector3: (130.309262975, 13.691125, 0.0)
#
# Cell for sensor RVector3: (132.5, 13.429349108570722, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB680>	ID: 1306, Marker: 1, Size: 0.49721989830120783
# 	761 RVector3: (132.75419332500002, 13.398975, 0.0)
# 	725 RVector3: (131.53172815, 13.545050000000002, 0.0)
# 	763 RVector3: (131.97469262619106, 12.678648360000723, 0.0)
#
# Cell for sensor RVector3: (135.0, 13.170220820713029, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 1225, Marker: 1, Size: 0.5979061145521766
# 	724 RVector3: (134.70273054358802, 12.262123733893882, 0.0)
# 	721 RVector3: (135.25956125, 13.149250000000002, 0.0)
# 	22 RVector3: (133.9766585, 13.2529, 0.0)
#
# Cell for sensor RVector3: (137.5, 12.968237466947516, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB680>	ID: 1224, Marker: 1, Size: 0.7159534327240881
# 	710 RVector3: (136.542464, 13.045600000000002, 0.0)
# 	717 RVector3: (137.50688187386785, 11.851535385145466, 0.0)
# 	714 RVector3: (137.82536675, 12.94195, 0.0)
#
# Cell for sensor RVector3: (140.0, 12.756808518915825, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 1215, Marker: 1, Size: 0.6321744960178963
# 	705 RVector3: (140.5641854, 12.70525, 0.0)
# 	23 RVector3: (139.1082695, 12.8383, 0.0)
# 	712 RVector3: (139.6732376370354, 11.918248228693466, 0.0)
#
# Cell for sensor RVector3: (142.5, 12.528344086320509, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB680>	ID: 1119, Marker: 1, Size: 0.8925400698028656
# 	666 RVector3: (142.02010130000002, 12.572199999999999, 0.0)
# 	676 RVector3: (142.8988762802738, 11.265805069680752, 0.0)
# 	675 RVector3: (143.4760172, 12.439150000000001, 0.0)
#
# Cell for sensor RVector3: (145.0, 12.299724969723627, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 1122, Marker: 1, Size: 0.7112484889292401
# 	665 RVector3: (145.3931950110873, 11.134798640846046, 0.0)
# 	663 RVector3: (146.19289980000002, 12.187999999999999, 0.0)
# 	24 RVector3: (144.9319331, 12.3061, 0.0)
#
# Cell for sensor RVector3: (147.5, 12.065579214724703, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB680>	ID: 1144, Marker: 1, Size: 0.4778657413409204
# 	673 RVector3: (148.7148332, 11.951800000000002, 0.0)
# 	623 RVector3: (147.4538665, 12.0699, 0.0)
# 	677 RVector3: (147.97627488328246, 11.263036573116871, 0.0)
#
# Cell for sensor RVector3: (150.0, 11.83095546738314, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 1154, Marker: 1, Size: 0.949169765901959
# 	688 RVector3: (151.2177542, 11.69285, 0.0)
# 	25 RVector3: (149.9757999, 11.8337, 0.0)
# 	611 RVector3: (150.29530293240543, 10.268955199069548, 0.0)
#
# Cell for sensor RVector3: (152.5, 11.547430542190643, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB680>	ID: 1037, Marker: 1, Size: 0.7977333329255729
# 	679 RVector3: (152.4597085, 11.552, 0.0)
# 	682 RVector3: (152.8371001948129, 10.22455801113975, 0.0)
# 	681 RVector3: (153.7016628, 11.41115, 0.0)
#
# Cell for sensor RVector3: (155.0, 11.264157270570397, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 920, Marker: 1, Size: 0.5535800520143955
# 	556 RVector3: (156.193540525, 11.134125000000001, 0.0)
# 	26 RVector3: (154.9436171, 11.2703, 0.0)
# 	680 RVector3: (154.9347382463932, 10.385484975320475, 0.0)
#
# Cell for sensor RVector3: (157.5, 10.991790585387262, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB680>	ID: 852, Marker: 1, Size: 0.6574535672067439
# 	553 RVector3: (157.98538532801558, 9.886919315808473, 0.0)
# 	551 RVector3: (158.69338737500001, 10.861775, 0.0)
# 	550 RVector3: (157.44346395000002, 10.99795, 0.0)
#
# Cell for sensor RVector3: (160.0, 10.719275039154573, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 820, Marker: 1, Size: 0.6149462900870817
# 	502 RVector3: (161.185327325, 10.587025, 0.0)
# 	27 RVector3: (159.9433108, 10.7256, 0.0)
# 	549 RVector3: (160.31456682228142, 9.693939504611814, 0.0)
#
# Cell for sensor RVector3: (162.5, 10.440343565195318, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB680>	ID: 800, Marker: 1, Size: 0.6009937484592665
# 	490 RVector3: (163.669360375, 10.309875000000002, 0.0)
# 	480 RVector3: (162.42734385, 10.448450000000001, 0.0)
# 	501 RVector3: (162.64291146557844, 9.456627625295834, 0.0)
#
# Cell for sensor RVector3: (165.0, 10.161591689490226, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 757, Marker: 1, Size: 0.8733772262322419
# 	468 RVector3: (166.1900629, 10.031225000000001, 0.0)
# 	28 RVector3: (164.9113769, 10.1713, 0.0)
# 	470 RVector3: (165.46825473928124, 8.744241976527613, 0.0)
#
# Cell for sensor RVector3: (167.5, 9.887726565448828, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB680>	ID: 748, Marker: 1, Size: 0.7494004840167524
# 	461 RVector3: (167.46874889999998, 9.891150000000001, 0.0)
# 	466 RVector3: (167.6575534679777, 8.698325672610016, 0.0)
# 	462 RVector3: (168.74743489999997, 9.751075000000002, 0.0)
#
# Cell for sensor RVector3: (170.0, 9.61386144140743, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 759, Marker: 1, Size: 0.6853544433060286
# 	462 RVector3: (168.74743489999997, 9.751075000000002, 0.0)
# 	467 RVector3: (169.40172481912657, 8.60743336551453, 0.0)
# 	29 RVector3: (170.0261209, 9.611, 0.0)
#
# Cell for sensor RVector3: (172.5, 9.42552453486764, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB680>	ID: 650, Marker: 1, Size: 0.554039537188579
# 	412 RVector3: (172.46764904999998, 9.427950000000001, 0.0)
# 	433 RVector3: (172.95287073161572, 8.483878158119305, 0.0)
# 	432 RVector3: (173.68841312499998, 9.336425, 0.0)
#
# Cell for sensor RVector3: (175.0, 9.238436017564906, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 645, Marker: 1, Size: 0.731898713220504
# 	30 RVector3: (174.9091772, 9.2449, 0.0)
# 	408 RVector3: (175.45492449595145, 8.035162580054656, 0.0)
# 	406 RVector3: (176.1593289, 9.155925, 0.0)
#
# Cell for sensor RVector3: (177.5, 9.060507610956334, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB680>	ID: 642, Marker: 1, Size: 0.7437685109617918
# 	342 RVector3: (177.4094806, 9.066949999999999, 0.0)
# 	403 RVector3: (177.97387264940787, 7.836896235709117, 0.0)
# 	402 RVector3: (178.6596323, 8.977974999999999, 0.0)
#
# Cell for sensor RVector3: (180.0, 8.880864629152246, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 530, Marker: 1, Size: 0.8440788733207091
# 	397 RVector3: (181.176188125, 8.774799999999999, 0.0)
# 	31 RVector3: (179.909784, 8.889, 0.0)
# 	366 RVector3: (180.66507745676992, 7.487857801884898, 0.0)
#
# Cell for sensor RVector3: (182.5, 8.655423165117217, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB680>	ID: 497, Marker: 1, Size: 0.8146649713719221
# 	320 RVector3: (182.44259225000002, 8.660599999999999, 0.0)
# 	321 RVector3: (182.96067583317625, 7.327301209661204, 0.0)
# 	322 RVector3: (183.70899637500003, 8.546399999999998, 0.0)
#
# Cell for sensor RVector3: (185.0, 8.43048744650877, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 493, Marker: 1, Size: 0.7073363508752872
# 	365 RVector3: (185.6283122580433, 7.26408025398676, 0.0)
# 	319 RVector3: (186.23550195, 8.344475, 0.0)
# 	32 RVector3: (184.9754005, 8.4322, 0.0)
#
# Cell for sensor RVector3: (187.5, 8.256443920092705, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB680>	ID: 440, Marker: 1, Size: 0.6247844021418352
# 	292 RVector3: (188.75570485, 8.169025000000001, 0.0)
# 	290 RVector3: (187.4956034, 8.256750000000002, 0.0)
# 	293 RVector3: (187.89441631114056, 7.2373442474604195, 0.0)
#
# Cell for sensor RVector3: (190.0, 8.082400393676638, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 437, Marker: 1, Size: 0.5575974578531896
# 	292 RVector3: (188.75570485, 8.169025000000001, 0.0)
# 	289 RVector3: (189.86997818195854, 7.206448102915695, 0.0)
# 	33 RVector3: (190.0158063, 8.0813, 0.0)
#
# Cell for sensor RVector3: (192.5, 7.861523019455551, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB680>	ID: 343, Marker: 1, Size: 0.7071930640447002
# 	252 RVector3: (193.69840447500002, 7.755499999999998, 0.0)
# 	234 RVector3: (192.47087175000001, 7.864099999999999, 0.0)
# 	253 RVector3: (192.8574657501712, 6.677679298663513, 0.0)
#
# Cell for sensor RVector3: (195.0, 7.634603004285264, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 329, Marker: 1, Size: 0.4812938886593071
# 	34 RVector3: (194.9259372, 7.6469, 0.0)
# 	251 RVector3: (194.95277186381495, 6.861582244900497, 0.0)
# 	229 RVector3: (196.15866135, 7.4422250000000005, 0.0)
#
# Cell for sensor RVector3: (197.5, 7.2195162227048115, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB680>	ID: 278, Marker: 1, Size: 0.8153681438895397
# 	199 RVector3: (197.3913855, 7.237549999999997, 0.0)
# 	205 RVector3: (197.68708662643084, 5.865581327340088, 0.0)
# 	203 RVector3: (198.62410965, 7.032874999999999, 0.0)
#
# Cell for sensor RVector3: (200.0, 6.809630272943272, 0.0): <pgcore._pygimli_.Triangle object at 0x000002937DECB5A0>	ID: 266, Marker: 1, Size: 0.6946484998694913
# 	195 RVector3: (201.115435075, 6.664950000000001, 0.0)
# 	35 RVector3: (199.8568338, 6.8282, 0.0)
# 	197 RVector3: (200.2805253910419, 5.66940199069671, 0.0)

# %% [markdown]
# Nodes: 29,409 — the points/vertices in the mesh (your topography points plus all the automatically generated interior points)
# - Nodes (29,409) — these are the P1, P2, P3 corner points of each triangle where the Jacobian coordinates (x1, y1), (x2, y2), (x3, y3) are defined
#
# Cells: 57,712 — the individual triangles that fill the domain (this is what gets assigned resistivity values)
# - Cells (57,712) — these are the triangles described in your theory, each defined by 3 nodes arranged CCW with points P1, P2, P3. Each triangle has its own mesh quality Jacobian computed from those coordinates.
#
# Boundaries: 43,836 — the edges shared between triangles, used to apply boundary conditions in the FEM solver
# - Boundaries (43,836) — these are the edges between triangles, which in FEM are used to assemble the element matrices (Si, St in your createJacobian code)

# %%
fop = ert.ERTModelling()
fop.setData(scheme)
fop.setMesh(mesh)

model = np.ones(mesh.cellCount())
fop.verbose = True
#This runs one forward solve and computes J for that single model state
# No inversion, no iteration — just coverage
fop.createJacobian(model)

print(f'jacobian size: {len(fop.jacobian())} rows, {len(fop.jacobian()[0])} columns')
print(f'parameter mesh nodes ({mesh.nodeCount()}), cells ({mesh.cellCount()}), and boundaries ({mesh.boundaryCount()})')
# Out:
# 22/04/26 - 14:56:42 - pyGIMLi - INFO - Found 1 regions.
# 22/04/26 - 14:56:42 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 22/04/26 - 14:56:42 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 22/04/26 - 14:56:42 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 13345 Cells: 25816 Boundaries: 19798
# jacobian size: 2926 rows, 6454 columns
# parameter mesh nodes (3446), cells (6454), and boundaries (9899)

# %%
def getABMN(scheme, idx):
    """ Get coordinates of four-point cfg with id `idx` from DataContainerERT
    `scheme`."""
    coords = {}
    for elec in "abmn":
        elec_id = int(scheme(elec)[idx])
        elec_pos = scheme.sensorPosition(elec_id)
        coords[elec] = elec_pos.x(), elec_pos.y()
        # print(f"{elec}: x={elec_pos.x()}")

    return coords


def plotABMN(ax, scheme, idx):
    """ Visualize four-point configuration on given axes. """
    coords = getABMN(scheme, idx)
    for elec in coords:
        x, y = coords[elec]
        if elec in "ab":
            color = "red"
        else:
            color = "blue"
        ax.plot(x, y, marker=".", color=color, ms=10)
        ax.annotate(elec.upper(), xy=(x, y), ha="center", fontsize=10, bbox=dict(
            boxstyle="round", fc=(0.8, 0.8, 0.8), ec=color), xytext=(0, 20),
                    textcoords='offset points', arrowprops=dict(
                        arrowstyle="wedge, tail_width=.5", fc=color, ec=color,
                        patchA=None, alpha=0.75))
        ax.plot(coords["a"][0],)

def calc_res_mat(jacobian):
    temp_a = pg.utils.gmat2numpy(jacobian).transpose()
    A = np.matmul(temp_a.transpose(),temp_a)
    B = temp_a.transpose()
    resolution_matrix = sp.linalg.solve(A,B)
    return resolution_matrix

# %%
measure = 25

nplots = len(range(0, len(fop.jacobian()), measure))

fig, ax = plt.subplots(
    nplots, 1,
    sharex=True,
    figsize=(16, 3*nplots)   # width , height per plot
)

for j, i in enumerate(range(0, len(fop.jacobian()), measure)):
    print(f'running measurement {i}...')

    sens = fop.jacobian()[i]

    plotABMN(ax[j], scheme, i)
    resolution_matrix = calc_res_mat(fop.jacobian())


    # normalize by cell size
    normsens = pg.utils.logDropTol(sens/mesh.cellSizes(), 8e-4)

    if i==0:
        norm_sum = np.abs(normsens)
        res_sum = resolution_matrix[i,:]
    else:  # cumulative
        norm_sum = norm_sum+np.abs(normsens)
        res_sum = res_sum+resolution_matrix[i,:]

    # normalize to max
    normsens = np.abs(normsens)
    normsens /= np.max(normsens)

    # from testing
    plotABMN(ax[0], scheme, i)
    pg.show(mesh,normsens, cMap="jet", orientation="vertical",
        label="Normalized Sensitivity", nLevs=3,ax=ax[0])

    # from combining
    # plotABMN(ax[j], scheme, i)
    # resolution_matrix = calc_res_mat(fop.jacobian())

    pg.show(mesh, normsens,
            cMap="jet", ax=ax[j], orientation="vertical", label="Normalized\nsensitivity", nLevs=3,
            cMin=-1, cMax=1)
    ax[j].set_title(f"Measurement {i}")
    
    plt.close()

plt.tight_layout()
# Out:
# running measurement 0...
# C:\Users\sydne\AppData\Local\Temp\ipykernel_36848\200457072.py:35: LinAlgWarning: An ill-conditioned matrix detected: slice 0 has rcond = 5.258325756004943e-22.
#   resolution_matrix = sp.linalg.solve(A,B)
# running measurement 25...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 120 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 50...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 121 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 75...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 122 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 100...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 123 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 125...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 124 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 150...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 125 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 175...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 126 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 200...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 127 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 225...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 128 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 250...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 129 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 275...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 130 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 300...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 131 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 325...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 132 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 350...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 133 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 375...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 134 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 400...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 135 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 425...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 136 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 450...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 137 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 475...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 138 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 500...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 139 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 525...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 140 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 550...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 141 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 575...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 142 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 600...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 143 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 625...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 144 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 650...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 145 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 675...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 146 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 700...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 147 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 725...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 148 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 750...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 149 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 775...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 150 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 800...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 151 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 825...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 152 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 850...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 153 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 875...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 154 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 900...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 155 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 925...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 156 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 950...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 157 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 975...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 158 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1000...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 159 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1025...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 160 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1050...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 161 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1075...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 162 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1100...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 163 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1125...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 164 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1150...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 165 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1175...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 166 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1200...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 167 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1225...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 168 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1250...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 169 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1275...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 170 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1300...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 171 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1325...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 172 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1350...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 173 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1375...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 174 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1400...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 175 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1425...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 176 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1450...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 177 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1475...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 178 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1500...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 179 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1525...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 180 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1550...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 181 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1575...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 182 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1600...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 183 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1625...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 184 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1650...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 185 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1675...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 186 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1700...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 187 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1725...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 188 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1750...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 189 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1775...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 190 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1800...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 191 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1825...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 192 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1850...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 193 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1875...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 194 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1900...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 195 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1925...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 196 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1950...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 197 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 1975...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 198 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2000...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 199 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2025...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 200 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2050...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 201 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2075...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 202 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2100...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 203 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2125...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 204 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2150...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 205 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2175...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 206 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2200...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 207 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2225...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 208 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2250...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 209 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2275...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 210 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2300...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 211 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2325...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 212 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2350...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 213 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2375...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 214 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2400...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 215 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2425...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 216 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2450...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 217 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2475...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 218 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2500...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 219 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2525...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 220 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2550...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 221 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2575...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 222 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2600...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 223 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2625...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 224 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2650...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 225 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2675...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 226 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2700...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 227 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2725...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 228 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2750...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 229 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2775...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 230 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2800...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 231 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2825...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 232 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2850...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 233 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2875...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 234 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2900...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 235 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)
# running measurement 2925...
# c:\Users\sydne\anaconda3\envs\pg\Lib\site-packages\pygimli\viewer\mpl\colorbar.py:319: UserWarning: Adding colorbar to a different Figure <Figure size 1600x35400 with 236 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   cbar = cbarTarget.colorbar(gci, cax=cax, orientation=orientation)

# %%
norm_sum /= np.max(norm_sum)
sens_sum = norm_sum

fig, ax = plt.subplots(figsize=(16, 8), dpi=400)

pg.show(mesh, sens_sum, cMap="jet", orientation="vertical",
        label="Normalized \n Cumulative Sensitivity", nLevs=3, cMin=0, cMax=1, ax=ax)

ax.set_xlabel('Distance (m)')
ax.set_ylabel('Elevation (m)')
ax.set_title(f'Cumulative Sensitivity at {measure}-Measurement Intervals')

fig.savefig(r"figures/line05/final_jacobian/3cumsens_max1.png", dpi=400, bbox_inches='tight')

#####

res_sum /= np.max(res_sum)

fig, ax = plt.subplots(figsize=(16, 8), dpi=400)

pg.show(mesh, res_sum, cMap="turbo", orientation="vertical",
        label="Normalized \n Cumulative Resolution",nLevs=3,cMin=0,cMax=1, ax=ax)

ax.set_xlabel('Distance (m)')
ax.set_ylabel('Elevation (m)')
ax.set_title(f'Cumulative Resolution at {measure}-Measurement Sampling Intervals')

fig.savefig(r"figures/line05/final_jacobian/4cumreso_max1.png", dpi=400, bbox_inches='tight')

# %%
norm_sum /= np.max(norm_sum)
sens_sum = norm_sum

fig, ax = plt.subplots(figsize=(16, 8), dpi=400)

pg.show(mesh, sens_sum, cMap="jet", orientation="vertical",
        label="Normalized \n Cumulative Sensitivity", nLevs=3, cMin=0, cMax=0.7, ax=ax)

ax.set_xlabel('Distance (m)')
ax.set_ylabel('Elevation (m)')
ax.set_title(f'Cumulative Sensitivity at {measure}-Measurement Intervals')

fig.savefig(r"figures/line05/final_jacobian/3cumsens_max07.png", dpi=400, bbox_inches='tight')

#####

res_sum /= np.max(res_sum)

fig, ax = plt.subplots(figsize=(16, 8), dpi=400)

pg.show(mesh, res_sum, cMap="turbo", orientation="vertical",
        label="Normalized \n Cumulative Resolution",nLevs=3,cMin=0,cMax=0.7, ax=ax)

ax.set_xlabel('Distance (m)')
ax.set_ylabel('Elevation (m)')
ax.set_title(f'Cumulative Resolution at {measure}-Measurement Intervals')

fig.savefig(r"figures/line05/final_jacobian/4cumreso_max07.png", dpi=400, bbox_inches='tight')
